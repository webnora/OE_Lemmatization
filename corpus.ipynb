# %%
from corpus import Corpus

lm = Corpus()
lm.parse()
# Out:
# FILE: resignation.txt
# All words: 516
# Forms not found: 348
# Lemms not found: 199
#
# FILE: soul and body i.txt
# All words: 729
# Forms not found: 471
# Lemms not found: 258
#
# FILE: the panther.txt
# All words: 317
# Forms not found: 237
# Lemms not found: 151
#
# FILE: a proverb from winfrids time.txt
# All words: 10
# Forms not found: 10
# Lemms not found: 8
#
# FILE: the rune poem.txt
# All words: 461
# Forms not found: 307
# Lemms not found: 193
#
# FILE: the husbands message.txt
# All words: 229
# Forms not found: 171
# Lemms not found: 103
#
# FILE: aldhelm.txt
# All words: 83
# Forms not found: 64
# Lemms not found: 46
#
# FILE: the capture of the five boroughs.txt
# All words: 55
# Forms not found: 47
# Lemms not found: 33
#
# FILE: guthlac a b.txt
# All words: 6099
# Forms not found: 4409
# Lemms not found: 1938
#
# FILE: exodus.txt
# All words: 2695
# Forms not found: 1933
# Lemms not found: 1048
#
# FILE: bedes death song west saxon version.txt
# All words: 21
# ...
